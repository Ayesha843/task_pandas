# %%
import pandas as pd 
df=pd.read_csv("D:\\titanic_final.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.set_index('PassengerId',inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.columns()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].unique
# Out:
# <bound method Series.unique of PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64>

# %%
female_survivors = df.loc[(df['Sex'] == 'female') & (df['Survived'] == 1)]#filtering only the female who survive 1 respresnt servive

# %%
female_survivors
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 875                 1       2
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 888                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...

# %%
 #age and fare of passengers who survived and were in third class:

age_fare_survived_third_class = df.loc[(df['Survived'] == 1) & (df['Pclass'] == 3), ['Age', 'Fare','Name']]

# %%
age_fare_survived_third_class
# Out:
#               Age     Fare                                               Name
# PassengerId
# 3            26.0   7.9250                             Heikkinen, Miss. Laina
# 9            27.0  11.1333  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 11            4.0  16.7000                    Sandstrom, Miss. Marguerite Rut
# 20            NaN   7.2250                            Masselmani, Mrs. Fatima
# 23           15.0   8.0292                        McGowan, Miss. Anna "Annie"
# ...           ...      ...                                                ...
# 839          32.0  56.4958                                    Chip, Mr. Chang
# 856          18.0   9.3500                         Aks, Mrs. Sam (Leah Rosen)
# 859          24.0  19.2583              Baclini, Mrs. Solomon (Latifa Qurban)
# 870           4.0  11.1333                    Johnson, Master. Harold Theodor
# 876          15.0   7.2250                   Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
age_by_gender=df.groupby('Sex')['Age'].mean()#average of percenger on gender

# %%
age_by_gender
# Out:
# Sex
# female    27.254777
# male      29.281057
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df['Ticket'].unique
# Out:
# <bound method Series.unique of PassengerId
# 1             A/5 21171
# 2              PC 17599
# 3      STON/O2. 3101282
# 4                113803
# 5                373450
#              ...
# 887              211536
# 888              112053
# 889          W./C. 6607
# 890              111369
# 891              370376
# Name: Ticket, Length: 891, dtype: object>

# %%
total_fare_by_class = df.groupby('Pclass')['Fare'].sum()#the total all fare from 1,2,3 class

# %%
total_fare_by_class
# Out:
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %%
#filtering by  person name
filtr1=df.loc[df['Name']=='Futrelle, Mrs. Jacques Heath (Lily May Peel)']

# %%
filtr1
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 4            female  35.0      1      0  113803  53.1  C123        S

# %%
#comparing 1,2,3 class the top highest fare paid person from all three class

max_fare_passengers = df.loc[df.groupby('Pclass')['Fare'].idxmax()]#idmax Compute the index of the maximum value in each group

# %%
max_fare_passengers
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 258          259         1       1            Ward, Miss. Anna  female  35.0
# 72            73         0       2        Hood, Mr. Ambrose Jr    male  21.0
# 159          160         0       3  Sage, Master. Thomas Henry    male   NaN
#
#      SibSp  Parch        Ticket      Fare Cabin Embarked
# 258      0      0      PC 17755  512.3292   NaN        C
# 72       0      0  S.O.C. 14879   73.5000   NaN        S
# 159      8      2      CA. 2343   69.5500   NaN        S

# %%
#comaring the maximum fare with gender
final=pd.concat([max_fare_passengers,age_by_gender],axis='columns',sort=False)

# %%
final
# Out:
#         PassengerId  Survived  Pclass                        Name     Sex  \
# 72             73.0       0.0     2.0        Hood, Mr. Ambrose Jr    male
# 159           160.0       0.0     3.0  Sage, Master. Thomas Henry    male
# 258           259.0       1.0     1.0            Ward, Miss. Anna  female
# female          NaN       NaN     NaN                         NaN     NaN
# male            NaN       NaN     NaN                         NaN     NaN
#
#          Age  SibSp  Parch        Ticket      Fare Cabin Embarked        Age
# 72      21.0    0.0    0.0  S.O.C. 14879   73.5000   NaN        S        NaN
# 159      NaN    8.0    2.0      CA. 2343   69.5500   NaN        S        NaN
# 258     35.0    0.0    0.0      PC 17755  512.3292   NaN        C        NaN
# female   NaN    NaN    NaN           NaN       NaN   NaN      NaN  27.254777
# male     NaN    NaN    NaN           NaN       NaN   NaN      NaN  29.281057

# %%
df['Embarked']
# Out:
# PassengerId
# 1      S
# 2      C
# 3      S
# 4      S
# 5      S
#       ..
# 887    S
# 888    S
# 889    S
# 890    C
# 891    Q
# Name: Embarked, Length: 891, dtype: object

# %%
male_passenger = df.loc[(df['Passenger'] == 'male') & (df['Survived'] == 1), 'Age'].agg(['min', 'max', 'mean'])#averge of pansenger who servive maemale_passenger

# %%
male_passenger
# Out:
# min      0.420000
# max     80.000000
# mean    27.276022
# Name: Age, dtype: float64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 24.00    207
# 22.00     27
# 18.00     26
# 19.00     25
# 30.00     25
#         ...
# 36.50      1
# 74.00      1
# 0.92       1
# 70.50      1
# 12.00      1
# Name: Age, Length: 88, dtype: int64

# %%
#to fill na value
df["Age"].fillna(value=df['Age'].mode()[0],inplace=True)

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  , 24.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 46.  , 59.  , 71.  ,
#        37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 , 51.  ,
#        55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  , 45.5 ,
#        20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  ,
#        10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  , 70.  ,
#        24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
d1=df.copy()

# %%
d1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.loc[d1['Name'].isin(['Braund, Mr. Owen Harris'])]#to check the name
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
g=df.groupby('Pclass')

# %%
g

# %%
for Pclass, Pclass_df in g:# To veiw the group of 3 class
    print(Pclass)
    print(Pclass_df)
    print()
# Out:
# 1
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ...

# %%
g.get_group(1)# to retive only 1 class data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(by=['Name','Age'],ascending=[False,True],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 868          869         0       3            van Melkebeke, Mr. Philemon
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 286          287         1       3                de Mulder, Mr. Theodore
# ..           ...       ...     ...                                    ...
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# 308          309         0       2                    Abelson, Mr. Samuel
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 845          846         0       3                    Abbing, Mr. Anthony
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
e=df.groupby('Embarked')

# %%
e

# %%
for embark, embark_df in e:# To veiw the group of 3 class
    print(embark)
    print(embark_df)
    print()
# Out:
# C
#      PassengerId  Survived  Pclass  \
# 361          362         0       2
# 240          241         0       3
# 111          112         0       3
# 495          496         0       3
# 354          355         0       3
# ..           ...       ...     ...
# 700          701         1       1
# 493          494         0       1
# 207          208         1       3
# 874          875         1       2
# 308          309         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 361                          del Carlo, Mr. Sebastiano    male  29.0      1
# 240                              Zabour, Miss. Thamine  female  24.0      1
# 111                               Zabour, Miss. Hileni  female  14.5      1
# 495                              Yousseff, Mr. Gerious    male  24.0      0
# 354                                  Yousif, Mr. Wazli    male  24.0      0
# ...

# %%
#mbark_from=e['Embarked'].apply(elambda x:x.str.contains("Embarde"))

# %%
count_C_S = df['Embarked'].apply(lambda x: x in ['C', 'S'])

# %%
count_C_S
# Out:
# 868    True
# 153    True
# 361    True
# 282    True
# 286    True
#        ...
# 874    True
# 308    True
# 279    True
# 746    True
# 845    True
# Name: Embarked, Length: 891, dtype: bool
